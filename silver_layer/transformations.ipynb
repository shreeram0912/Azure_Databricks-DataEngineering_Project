# %% [markdown]
# #**Silver_Layer_Transformation**

# %% [markdown]
# ### **Import libraries**

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %% [markdown]
# ### **Establish connection**

# %%
# Connecting to Azure Data Lake 
spark.conf.set('fs.azure.account.key.datalakeazuredatabricks.dfs.core.windows.net', 'LuUWQy2pFP32+FiO94ok2cwkoyLWOI2zO2kFBtsCHBqt4t/ohW8squAMNX7wPMEzMebxoaHk3k5o+AStROC22A==')

# %%
filename = dbutils.fs.ls('abfss://bronze@datalakeazuredatabricks.dfs.core.windows.net')[0].name
filename

# %%
df = spark.read.parquet('abfss://bronze@datalakeazuredatabricks.dfs.core.windows.net')
df.display()

# %%
df.printSchema()

# %%
# Make column in camel case
df = df.withColumn("Country", initcap(df['Country']))
df = df.withColumn("ProductCategory", initcap(df['ProductCategory']))
df = df.withColumn("SalesRegion", initcap(df['SalesRegion']))
df = df.withColumn("ProductName", initcap(df['ProductName']))
df = df.withColumn("CustomerName", initcap(df['CustomerName']))

# %%
# Removing null values
df = df.dropna(how='all')

# %%
# Removing duplicate records
df = df.dropDuplicates()

# %%
df.write.format('parquet')\
        .mode('overwrite')\
        .option('path', 'abfss://silver@datalakeazuredatabricks.dfs.core.windows.net')\
        .save()
